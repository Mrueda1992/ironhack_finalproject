# %% [markdown]
# # _INSIDE TECH'S HYPE_
#
# Este Notebook contiene la extracción, la limpieza y la transformación de los datos necesarios para llevar a cabo el proyecto, que se realizará en otros archivos.
#
# En primer lugar, importamos las librerías con las que vamos a trabajar: Requests, BeautifulSoup y Pandas

# %%
from bs4 import BeautifulSoup as bs
import requests
import time
import re
import pandas as pd

# %% [markdown]
# Tras importar las librerías, comenzamos a scrapear la página web seleccionada. El primer paso es obtener, a través de las urls de las secciones del blog, la mayor cantidad de links a noticias posible.

# %%
url = 'https://hackernoon.com/tagged/'
feat_list = ['cryptocurrency','coding','artificial-intelligence',
             'futurist','startups']

lista_articulos = []
for features in feat_list:
    res = requests.get(url+features)
    page = res.content
    soup = bs(page, 'html.parser')
    for article in soup.find_all('div',{'class':'title'}):
        news = article.find('a', href=True)
        lista_articulos.append('https://hackernoon.com' + news.get('href'))

# %%
print(len(lista_articulos))
# Out:
# 360

# %% [markdown]
# Hemos comprobado el número de links que hemos conseguido: 360. Un número que a priori es escaso pero que, debido a los plazos de entrega, damos por válido para continuar el análisis. El siguiente paso es extraer la información que es relevante para el proyecto: el texto del artículo, el título y los 'tags' que aparecen en cada noticia.

# %%
tag_dict = dict()
title_list = []
text_list=[]
counter=0
counter2=1
counter3=0
counter4=1
start=time.time()
for url in lista_articulos:
    
    paragraph = []
    page = requests.get(url)
    soup = bs(page.text, 'html.parser')
    
    try:
        for t in soup.find_all('div',{'class':'paragraph'}):
            paragraph.append(t.text)
        text_list.append(' '.join(paragraph))
        
    except:
        raise ValueError
  
    try:   
        
        for title in soup.find('h1', {'class':'title'}):
            if title in title_list:
                title_list.append(title+str(counter2))
                counter2+=1
            else:
                title_list.append(title)
    except:
        
        title = "No title" + str(counter)
        counter+=1
        title_list.append(title)

    tags = []
    
    for i in soup.find_all('div', {'class':'archive-tags'}):
        tags_str=i.text.split('\n')[1:-1]
    tags.append(tags_str)   
    counter4+=1
    tag_dict[str(counter4)]=tags

end = time.time()
print(end-start)
# Out:
# 311.5912640094757

# %%
print(text_list[0])
# Out:
# Financial markets are chaotic. So chaotic, even, that many economists and investors believe market trends to be the product of ârandom walksâ and that prices cannot be predicted (see generallyÂ Malkiel). But randomness shouldn't be worrisome. In fact, random price movements can be good. Gaussian random walk, an assumption used by an options pricing model called Black-Scholes, treats intervals of an assetâs price over time as independent variables. By doing so, the changes in price over time, or the returns of an asset, are assumed to be normally distributed. Otherwise stated, âIf transactions are fairly uniformly spread across time, and if the number of transactions per day, week, or month is very large, then the Central Limit Theorem leads us to expect that these price changes will have normal or Gaussian distributionsâ (Fama, 399). When an asset's returns are normally distributed, the probabilities of those returns are known. Knowing these probabilities can give investors a reliable framework accounting for the risk of holding said asset. When it comes to bitcoin, much has been said about how risky it is. The purpose of this article is to explore how to frame risk and to test how well traditional assumptions, implicit in derivatives pricing, apply to bitcoin.  This article will proceed by introducing the derivatives market and giving an overview of the Black-Scholes model. After a brief discussion of why the Black-Scholes model is important and what it does, I will highlight the weaknesses of the model and the (sometimes) unrealistic assumptions it makes. I will then turn to how well the model fits into the bitcoin derivatives market. Particularly, I will show that historical data on daily bitcoin returns from January 2016 till August 2019 exhibitÂ excessÂ kurtosis.Â Following a discussion of the findings, I will compare the efficacy of Black-Scholes applied to bitcoin with the S&P 500. Finally, the article will end with closing thoughts on why the Black-Scholes model may poorly fit the crypto market and the implications this presents for the future of the quickly growing crypto derivatives market. Imagine that youâre a farmer and you expect to produce 5,000 bushels of corn. Naturally, you want to sell the corn for as much as you can. However, because prices are subject to the demands of an unrelenting market, thereâs a possibility that corn may be selling below your production costs after the harvest. Financial derivatives can be used to minimize the total loss suffered by an unexpected crash. If the price of corn is trading for around $3.50/bushel and you would like to âlock-inâ a price floor of $3, you could buy a put option at $3 and be safe from a possibility where the price went below $3. Since put options increase in value as the underlying asset trades below its strike price, the price at which the option is purchased, the total loss is the cost of the option. If the cost of the put option at $3 is 10 cents ($500=5000*.10) and if the production costs of corn is $1/bushel, then the minimum profit is $9500. The purpose of the above example is to highlight the utility of derivatives. Of course, the picture of a farmerâs derivatives portfolio can become increasingly more complicated when considering how to use a full suite of futures, options, swaps, etc. Yet, a basic intuition can be gleamed: markets and prices reflect uncertainty/risk and derivatives exist as products to minimize such uncertainty. With this understanding of derivatives, the price of any derivative takes on a special consideration. For, the derivativeâs instrumentality is premised upon its ability to represent an actual hedge against the uncertainty of the underlying asset. In the above example, if the price of the put option was $2, instead of 10 cents, and corn was trading at $3.50, the state of the options market can tell you a number of things about the broader corn market. First, if the option is accurately priced and not the  ...

# %% [markdown]
# Hemos extraído el contenido de la página en dos listas (title_list y text_list) y un diccionario (tag_dict). Al ver el texto, observamos que hay palabras con caracteres raros. Limpiamos estos términos con expresiones regulares.

# %%
#regex to clean text format
def regexTitle(s):
    lst=[]
    for text in s:
        lst.append(re.sub('[âÂ]\S*','', text))
    return lst

title_list=regexTitle(title_list)
text_list=regexTitle(text_list)

# %% [markdown]
# Creamos un diccionario con el contenido extraído de Hackernoon para convertir posteriormente en un dataframe con Pandas

# %%
articles_dict = {"id": lista_articulos, "title": title_list, "text": text_list}

# %%
articles = pd.DataFrame.from_dict(articles_dict)
articles['tags'] = tag_dict.values()
articles.shape
# Out:
# (360, 4)

# %%
articles.tags
# Out:
# 0      ([Bitcoin, Blockchain, Finance, Investment, Cr...
# 1      ([Venture Capital, Self Custodian Bank, Crypto...
# 2      ([Cryptocurrency, Ethereum, Blockchain, Machin...
# 3      ([Scott Stornetta, Cryptocurrency, End User, E...
# 4      ([Crypto Exchanges, Latest Tech Stories, Hacke...
#                              ...
# 355    ([Startup, Product Management, Culture, Startu...
# 356    ([Product Management, Startups, Startup, Manag...
# 357    ([Instacart, Technology, Amazon, Predictions, ...
# 358    ([Instacart, Technology, Amazon, Predictions, ...
# 359    ([Startup, Management, Agile, Startups, Produc...
# Name: tags, Length: 360, dtype: object

# %% [markdown]
# Como podemos observar, tenemos varios tags para cada artículo encapsulados en una lista. Además, el objeto es una tupla en la que el primer valor es un índice. Eliminamos el índice para quedarnos con la lista de tags, que posteriormente modificaremos también para quedarnos con un solo tag por artículo.

# %%
articles.tags = [e[0] for e in articles.tags]

# %% [markdown]
# Hay artículos de los que no se ha obtenido texto, pues estaban dentro de una etiqueta HTML distinta. Eliminamos estos registros.

# %%
articles = articles[articles.text != '']
articles.head()
# Out:
#                                                   id  \
# 0  https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 1  https://hackernoon.com/why-we-invested-in-mult...
# 2  https://hackernoon.com/five-fascinating-data-v...
# 3  https://hackernoon.com/founding-father-of-bloc...
# 4  https://hackernoon.com/the-curious-case-of-cry...
#
#                                                title  \
# 0     Kurtosis and Bitcoin: A Quantitative Analysis
# 1  Why We Invested in Multis, The Self Custodian ...
# 2  Centralized Crypto Exchanges Explained in 5 Fa...
# 3  Founding father of Blockchain Scott Stornetta ...
# 4               The Curious Case of Crypto-Exchanges
#
#                                                 text  \
# 0  Financial markets are chaotic. So chaotic, eve...
# 1  We are excited to announce our investment in M...
# 2  Centralized exchanges are, arguably, one of th...
# 3  Dr. Scott Stornetta is the blockchain co-inven...
# 4  Hacker Noon contributors evaluated the industr...
#
#                                                 tags
# 0  [Bitcoin, Blockchain, Finance, Investment, Cry...
# 1  [Venture Capital, Self Custodian Bank, Cryptoc...
# 2  [Cryptocurrency, Ethereum, Blockchain, Machine...
# 3  [Scott Stornetta, Cryptocurrency, End User, El...
# 4  [Crypto Exchanges, Latest Tech Stories, Hacker...

# %% [markdown]
# A continuación, creamos una función para extraer los tags de la lista y pasarlos a registros independientes

# %%
def tagSeparator(df):
    s = df.tags.apply(pd.Series,1).stack()
    s.index=s.index.droplevel(-1)
    s.name = 'Tags'
    return df.join(s)

new_articles= tagSeparator(articles)

new_articles.drop('tags', axis=1, inplace=True)
type(new_articles)
# Out:
# pandas.core.frame.DataFrame

# %%
new_articles.Tags.unique()
# Out:
# array(['Bitcoin', 'Blockchain', 'Finance', 'Investment', 'Cryptocurrency',
#        'Hackernoon Top Story', 'Kurtosis', 'Kurtosis And Bitcoin',
#        'Venture Capital', 'Self Custodian Bank', 'Cryptocurrency Bank',
#        'Fintech', 'Multis', 'Gnosis', 'Ethereum', 'Machine Learning',
#        'Crypto Exchanges', 'Centralized Crypto Exchanges',
#        'Data Visualizations', 'Scott Stornetta', 'End User',
#        'Electroneum', 'Regulations', 'Latest Tech Stories',
#        'Moderated Centralisation', 'Good Company',
#        'Hacker Noon Newsletter', 'Decentralized Exchanges',
#        'Cryptocurrency Liquidity', 'Trading Volume Cryptocurrency',
#        'Cryptocurrency Exchange', 'Craig Wright', 'Binance', 'Quantopian',
#        'Crypto', 'Custody', 'Storing Digital Assets', 'Banking',
#        'Custodianship Of Assets', 'Digital Asset',
#        'Institutional Grade Custody', 'Cold Wallet', 'Hot Wallet',
#        'Multi Signature Wallet', 'Tech Newsletter', 'Decentralization',
#        'Software Development', 'Startups', 'Valuation', 'Token', 'Cry',
#        'Ieo', 'Latest Tech Story', 'Erc721', 'Triple Entry',
#        'Collectibles', 'Defi', 'Nft', 'Dao', 'Trading', 'Bots', 'Coins',
#        'Initial Exchange Offerings', 'Trading Bots', 'Staking',
#        'Passive Income', 'Generating Passive Income', 'Proof Of Stake',
#        'Disadvantages Of Staking', 'Advantages Of Staking', 'Vwampp',
#        'Volume Weighted Average', 'Coinmarketcap', 'Bitcoin Real Price',
#        'Currency Pairs', 'Crypto Trends', 'Financial Markets',
#        'Crypto Trade', 'Digital Wallet', 'Cryptocurrency Platform', 'Eos',
#        'Projection', 'Altcoins', 'Giving', 'Philanthropy', 'Charity',
#        'Fundraising', 'Social Impact', 'Crypto For Good',
#        'Consensus Algorithm', 'Dpos', 'Delegated Proof Of Stake',
#        'Byzantine Fault Tolerance', 'Lisk Architecture',
#        'Security Tokens', 'Tokenization', 'Sto', 'Crypto Research Report',
#        'Sharding', 'What Is Sharding', 'Blockchain Sharding', 'Education',
#        'Crypto Transactions', 'Crypto Payments', 'Is Crypto Risky',
#        'How To Secure Your Crypto', 'Mathematics', 'Tech Politics',
#        'Politics', 'Recession', 'Career', 'Tech', 'Investing', 'Quant',
#        'Intotheblock', 'Crypto Assets', 'Algorand', 'Libra', 'Trust',
#        'Consensus', 'Facebook', 'Altcoin', 'Crypto Exchange',
#        'Crypto Exchange Review', 'Peer To Peer Trading', 'Crypto Wallets',
#        'Coin Wallet Review', 'Jaxx Review', 'Freewallet Review',
#        'Crypto Wallets Reviewed', 'The Future Of Blockchain',
#        'Noam Levenson', 'Hackernoon Podcast', 'Hackernoon Originals',
#        'Podcasts', 'Crypto Writers', 'Ico', 'Steo', 'Crowdfunding',
#        'Follow The Money', 'Asset Class', 'Investment Opportunity',
#        'Us Interest Rates', 'Institutional Money', 'Research',
#        'Research Framework', 'Top Down Macro Approach',
#        'Bottom Up Security Selection', 'Token Design', 'Dapp',
#        'Legality Of Dapps', 'Crypto Wild West', 'Information Is Power',
#        'Speculation', 'Crypto Tokens', 'News Aggregator', 'Book Design',
#        'Ebooks', 'Bitcoin Spotlight', 'Featured Tech Stories', 'Business',
#        'Trading Algos', 'Utility Tokens', 'Replacing Fiat', 'Technology',
#        'Traditional', 'Database', 'Media Industry', 'Wordpress',
#        'Bitcoin Cash', 'Bitcoin Sv', 'Datascience', 'Machinelearning',
#        'Tax', 'Taxation', 'Industry', 'Disrupting', 'Regulation',
#        'Crypto Trading Bots', 'Automated Trading',
#        'Cryptocurrency Trading Bots', 'Versatile Cryptocurrency Bot',
#        'Bitcoin And Altcoins', 'P2p Exchange', 'Margin Trading',
#        'Leveraged Trading', 'Crypto Exchange Architecture',
#        'Headhunter Program', 'Personal Recruiter', 'Stablecoin',
#        'Payments', 'Blockchain Adoption', 'Decentralized', 'Gaming',
#        'Casino', 'Decentralized Gaming', 'Permissionless', 'Mining',
#        'Hardfork', 'Progpow', 'Eth', 'Louis Vuitton Gucci', 'Prada',
#        'Supply Chain Management', 'Counterfeits', 'Drop Gold Buy Bitcoin',
#        'Anthony Pompliano', 'Short The Banks Long Bitcoin',
#        'Story Of Cryptocurrency', 'Cyber Security', 'Iot', 'Transactions',
#        'Data', 'Data Science', 'Bch', 'Introduction To Bch',
#        'Adding Metadata To Crypto', 'Op_return', 'What Is Op_return',
#        'Dash', 'Litecoin', 'Forgery', 'Environment Conservation',
#        'Tree Felling', 'Paper Wastage', 'Fighting Forgery', 'Bot',
#        'Money', 'Credium', 'Bot Based Trading', 'Staking In Solidity',
#        'How To', 'Blockchain Development', 'Blockchain Architecture',
#        'Javascript', 'Nodejs', 'Event Loop', 'Threads',
#        'Asynchronous And Synchronous', 'Runtime Environments', 'Coding',
#        'Expo', 'Development', 'Expo Facebook', 'Expo Sdk',
#        'Softwareengineering', 'Design', 'Simple', 'Software',
#        'Engineering', 'Softwareengineering Complexity', 'Marketing',
#        'Growth Hacking', 'Web Scraping', 'Programming', 'Java', 'Python',
#        'C', 'Andela', 'Coding Assessments', 'Coding Tests',
#        'Talent Acquisition', 'Software Engineering', 'Sass', 'Html',
#        'Css', 'Junit', 'Mockito', 'Unit Testing', 'Api', 'Rest',
#        'Productivity', 'Tools', 'Testing', 'Web Development',
#        '10x Engineer', 'Company Culture', 'Careers',
#        '10x Engineers Memes', 'Brilliant Jerks', 'Developers',
#        'Serverless', 'Jobs', 'Interviews', 'Advice', 'Design Patterns',
#        'Probability', 'Simulation', 'Analytics', 'Computer Programming',
#        'Hacking', 'Life Story', 'Ruby', 'Linux', 'Tutorial',
#        'Authentication', 'Adding Authentication', 'Simpleid', 'Bash',
#        'Shell', 'Beginner', 'Zsh', 'Aspnet', 'Aspnet Core', 'Ninject',
#        'Di', 'Typescript', 'Codenewbie', 'Learn To Code', 'Coderlife',
#        'Python Social Auth', 'Create A Mock Backend', 'Test Redirect',
#        'Simulate Successful Return', 'Node', 'Js', 'Developer', 'Android',
#        'Open Source', 'Mobile', 'Architecture', 'Developer Assessments',
#        'Hackerrank', 'Qualifiedio', 'Codility', 'Angular', 'Webdev',
#        'Frontend', 'Full Stack Development Company',
#        'Full Stack Development', 'Full Stack Developer', 'Frameworks',
#        'Engineering Management', 'Software Developer', 'Debugging',
#        'Cybersecurity', 'Privacy', 'Security', 'Software Engineer',
#        'Ml Frameworks 2019', 'Ml Frameworks',
#        'Machine Learning Frameworks', 'Machine Learning Framework',
#        'Ml Framework', 'Product Development', 'App Development',
#        'Startup', 'Entrepreneur', 'Learning', 'Self Teaching', 'Newbie',
#        'Process', 'Remote', 'Office Culture', 'Startup Advice',
#        'To Remote Or Not To Remote', 'Working From Home', 'Beginners',
#        'Node Vs Rails', 'Why Choose Node', 'Code Talks', 'Codetalks',
#        'Codetalkstv', 'Mvp', 'Developer Community',
#        'Build A Side Project', 'React', 'Modal', 'Reactjs Popup',
#        'Programming Languages', 'Performance', 'Teamwork',
#        'Junior Developer', 'Learning To Code', 'Promises',
#        'Promiseallsettled', 'Promiseany', 'Machine Learning Libraries',
#        'Ml Libraries', 'Aws', 'Aws Lambda', 'Monorepo', 'Cloud',
#        'Interview', 'Leetcode', 'Technical Interviews',
#        'Coding Interviews', 'Vscode', 'Editor',
#        'Detailed Programming Guide', 'Visual Studio Code', 'Git',
#        'Laravel', 'Php', 'Local Projects', 'Practical Guide',
#        'Mdn Documentation', 'Use The Sandbox', 'Artificial Intelligence',
#        'Ai And Machine Learning', 'General Tech',
#        'Differences Between Ai And Ml', 'Tensorflow', 'Torch',
#        'Computer Vision', 'Image Annotation', 'Deep Learning',
#        'Semantic Segmentation', 'Fake News',
#        'Fake News Evaluation Network', 'Deep Fakes', 'Virality',
#        'Fake News Solution', 'Ai And Ml Applications',
#        'Optimize Operations', 'Hello Barbie', 'Watson Beat',
#        'Gps And The Farmsight System', 'Ai', 'Ai Development',
#        'Ml Development', 'Why Ai Fails', 'Cultural Ai Challenges',
#        'Operational Ai Challenges', 'Ai Data Challenges', 'Culture',
#        'Race', 'Diversity', 'Smart City', 'Et City Brain', 'City Brain',
#        'Rule The World', 'Alibaba', 'Smart Tech', 'Internet',
#        'Recommendation Systems', 'Personality', 'Choice', 'Ml', 'Sex',
#        'Ai And Sex', 'Ai Sex', 'Statistics',
#        'Fear Of Artificial Intellignce', 'Mass Surveillance',
#        'Ethical Implications', 'Emotion Ai', 'Conversational Ai',
#        'Voice Technology', 'Emotional Intelligence', 'Big Data',
#        'Ai Powered Tools', 'Ai Helps Startup Grow', 'Real Experiences',
#        'Ai Based Tools', 'Ai Market Potential', 'Disruptor',
#        'Disruptive Tech', 'Funding', 'Psychology', 'Cognitive Psychology',
#        'Neural Networks', 'Gaming Industry', 'Ar And Vr', 'Ar', 'Vr',
#        'Learn Artificial Intelligence', 'Intelligent Machines',
#        'Decision Making', 'Ai Courses', 'Ai And Smart Homes', 'Datasets',
#        'Overfitting', 'Small Data', 'Data Mining', 'Predictive Analytics',
#        'Personal Development', 'Human Computer Interaction', 'Analysis',
#        'Pitching', 'Presentations', 'Social Listening', 'Economy',
#        'Ai Economy', 'Ai Economics', 'Economics', 'Ai Market Size',
#        'Noonies', 'Hacker Noon Awards', 'Tech Awards', 'Tech Publishing',
#        'Noonies 2019', 'Ai Writer Of The Year', 'Data Organization',
#        'Digital Era', 'Optimize Business Processes', 'Voice',
#        'Facial Recognition', 'Data Privacy', '5g', 'E Commerce',
#        'Digital', 'Mobile Commerce', 'Music', 'Generative Music',
#        'Role Of Music For Business', 'Streaming Services',
#        'Personalized User Experience', 'Operating Systems',
#        'Reflinks Vs Symlinks', 'Value Of Gaming', 'Ai And Gaming',
#        'Automating Gaming', 'Gaming And Real World', 'Website',
#        'Website Builder', 'Talking Intelligence', 'Ai And Wordpress',
#        'Reinforcement Learning', 'Value Function', 'Explore Exploit',
#        'Ai And Ethics', 'Ethics', 'Technology Trends',
#        'Ai And Blockchain', 'Emerging Tech', 'Data Studies',
#        'Data Marketplace', 'Accessibility', 'Scaling', 'Ai Trends',
#        'Philosophy', 'Optimization', 'Stochastic Gradient Descent', 'Sgd',
#        'Neural Network And Blockchain', 'Ai Bias', 'College Admissions',
#        'College', 'Ai Myths', 'Internet Of Things', 'Ai And Iot',
#        'Ai Revolution', 'Iot Revolution', 'Audience', 'Digital Marketing',
#        'Analyze Competitors', 'Content Management',
#        'Distributed Ledger Technology', 'Learn Ai',
#        'Consuming To Creating', 'Mobile App Development', 'Ai In 2020',
#        'Future Of Ai', 'Hackernoon Tech Stories',
#        'Hackernoon Top Stories', 'Nlp', 'Search Engine', 'Algorithm',
#        'Data Augmentation', 'Unsupervised Data Augmentation',
#        'Supervised Learning', 'Unsupervised Learning', 'Applications',
#        'Smart Vehicles', 'Iot Applications', 'Ai Applications',
#        'Robotics', 'Driverless Cars', 'Tomorrowland', 'Crowdsourcing',
#        'Automation', 'Crowdwork', 'Job Automation', 'Erik Brynjolfsson',
#        'Futurism', 'Futurist', 'Another Future Thought',
#        'Another Thought', 'David Smooke', 'Future David Smooke',
#        'I See The World', 'Another Tech Thought', 'Hackernoon Medium',
#        'Medium Hackernoon', 'Ev Williams', 'Hackernoon', 'Medium', 'Kpis',
#        'Metrics', 'Product Management', 'Hard Metric',
#        'Find A Hard Metric', 'Women In Tech', 'Entrepreneurship',
#        'Female Founders', 'Startup Accelerators', 'Africa', 'Investments',
#        'Investing And Africa', 'Up And Coming Startups',
#        'Investor Attention', 'Best Stories', 'Faang', 'Faagm',
#        'Think Big', 'Work Hard', 'Henry Ford', 'Youre Right',
#        'Management', 'Software Interview Tips', 'Engineering Interviews',
#        'Traction And Burn', 'Product Pricing', 'Sales Management',
#        'Brand As Author', 'Accreditation As Advertisement',
#        'Digital Advertizing', 'Brand Author', 'Accreditation',
#        'Known Bias', 'User Experience', 'Doogfooding', 'Edge Cases',
#        'Cap Table', 'Sequoia Capital', 'Founders', 'Silicon Valley',
#        'Chatbot Development', 'Bot Development', 'Chatbots',
#        'Problem Solving', 'Product Management Advice', 'Product Roadmap',
#        'When To Pivot', 'Users Hate Change', 'Hackathon', 'Event',
#        'Meetup', 'Buzzwords', 'Not Just Another Meetup',
#        'Not Another Meetup', 'Tech Events', 'Marketing For Engineers',
#        'Tech Specs', 'Product Features', 'Bring Numbers To Life',
#        'Psychological Number Tricks', 'Imposter Syndrome', 'Podcast',
#        'Nontechnical Founder Interview', 'Tech Founder Interview',
#        'Hacker Podcast', 'Real Life', 'Expectations Vs Market Feedbac',
#        'Startup Evaluation', 'Self Evaluation Of Startup',
#        'Will My Startup Fail', 'What Does My Startup Need',
#        'Product Hunt', 'Promotion', 'Product Hunt Tips And Tricks',
#        'Product Hunt Tools', 'Product Hunt Growth Hacking',
#        'Founder Interviews', 'Founder Stories', 'Marketplace',
#        'Young Entrepreneurs', 'Gary Vaynerchuck',
#        'If Not College Then What', 'Brand Experience', 'Smb',
#        'Business Tools', 'Customer Service', 'Use Chatbots', 'Hack',
#        'Identity', 'Passbase', 'Democracy', 'Prototype', 'Entrepreneurs',
#        'Entreneurship', 'Why Prototype', 'Why Entrepreneurs Prototype',
#        'Prototyping', 'Angel Investors', 'Raising Capital', 'Saas',
#        'Conversion Optimization', 'Mailchimp', 'Customer Acquisiton',
#        'Business Model', 'First Principles', 'Startup Founders', 'Work',
#        'Hiring', 'Blueprints', 'Blueprint To Construction', 'Launch',
#        'Post Launch', 'Vision Function Spectrum', 'Data Analytics',
#        'Drones', 'Data Collection', 'Thermal Imaging', 'Drones Big Data',
#        'Drones Data', 'Robots', 'Human Robot Relationships', 'Robocist',
#        'Jibo', 'Sexbot', 'Lovotics', 'Technology Isolation',
#        'Tech For Good', 'Social Media', 'Brain Machine Interface',
#        'Autonomous Driving', 'Humanity', 'Rails', 'Twitter', 'Shopify',
#        'Github', 'Ruby On Rails', 'How To Build A Community',
#        'Crypto Collectibles', 'Ethereum Blockchain',
#        'How To Collaborate Effectively', 'Digital Collectible',
#        'Collectible Cards', 'Critical Thinking', 'Altcoin Review',
#        'Shitcoin', 'Donations On Blockchain', 'Decentralized Charity',
#        'Roger Dickey', 'Peter Thiel', 'Founders Fund', 'Founder', 'China',
#        'Jack Ma', 'Alibaba Story', 'Problemeter', 'Google Sheets',
#        'Startup Google Sheet', 'Lean Startup', 'Project Management',
#        'Communication', 'Estimating', 'Project Planning',
#        'Team Management', 'Feedback', 'Workshops', 'Startups Advice',
#        'Model Deployment', 'Executive Mba Program', 'Mba Program', 'Mba',
#        'Latet Tech Stories', 'University', 'Tech Career', 'Bootstrapping',
#        'Oregon Startups', 'Allie Magyar', 'Ios App Development', 'Swift',
#        'My Second Mobile App', 'Wisdom', 'Advisors', 'Bad Startup Advice',
#        'Tech Boom', 'Tech Boom Challenges', 'Technology Governance',
#        'Technology Boom'], dtype=object)

# %%
drop_tags = ['Top tech stories', 'Latest','Hacker noon awards', 'Tech awards','Noonies 2019',
                  'Hackernoon medium', 'Medium hackernoon', 'David smooke',
       'Ev williams', 'Hackernoon', 'Medium','Killing globalization',
       'Killing globalisation', 'I see the world','Wtf Is A Merkle Tree','What Is A Merkle Tree',
       'Another tech thought', 'Founders', 'Founder stories',
      'Problemeter','Latet tech stories', 'Promiseallsettled', 'Promiseany',' all encompassing enemy',
                 'Be for something', 'Erik Brynjolfsson']

new_articles[~new_articles.Tags.isin(drop_tags)]
# Out:
#                                                     id  \
# 0    https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 0    https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 0    https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 0    https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 0    https://hackernoon.com/kurtosis-and-bitcoin-uc...
# ..                                                 ...
# 353  https://hackernoon.com/technology-an-added-dim...
# 353  https://hackernoon.com/technology-an-added-dim...
# 353  https://hackernoon.com/technology-an-added-dim...
# 353  https://hackernoon.com/technology-an-added-dim...
# 353  https://hackernoon.com/technology-an-added-dim...
#
#                                               title  \
# 0    Kurtosis and Bitcoin: A Quantitative Analysis
# 0    Kurtosis and Bitcoin: A Quantitative Analysis
# 0    Kurtosis and Bitcoin: A Quantitative Analysis
# 0    Kurtosis and Bitcoin: A Quantitative Analysis
# 0    Kurtosis and Bitcoin: A Quantitative Analysis
# ..                                              ...
# 353       The Tech Boom's Unanticipated Challenges
# 353       The Tech Boom's Unanticipated Challenges
# 353       The Tech Boom's Unanticipated Challenges
# 353       The Tech Boom's Unanticipated Challenges
# 353       The Tech Boom's Unanticipated Challenges
#
#                                                   text                   Tags
# 0    Financial markets are chaotic. So chaotic, eve...                Bitcoin
# 0    Financial markets are chaotic. So chaotic, eve...             Blockchain
# 0    Financial markets are chaotic. So chaotic, eve...                Finance
# 0    Financial markets are chaotic. So chaotic, eve...             Investment
# 0    Financial markets are chaotic. So chaotic, eve...         Cryptocurrency
# ..                                                 ...                    ...
# 353  (a+b) = a + b + 2ab . Remember this age old ma...               Startups
# 353  (a+b) = a + b + 2ab . Remember this age old ma...             Technology
# 353  (a+b) = a + b + 2ab . Remember this age old ma...   Tech Boom Challenges
# 353  (a+b) = a + b + 2ab . Remember this age old ma...  Technology Governance
# 353  (a+b) = a + b + 2ab . Remember this age old ma...        Technology Boom
#
# [1580 rows x 4 columns]

# %%
new_articles.head()
# Out:
#                                                   id  \
# 0  https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 0  https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 0  https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 0  https://hackernoon.com/kurtosis-and-bitcoin-uc...
# 0  https://hackernoon.com/kurtosis-and-bitcoin-uc...
#
#                                             title  \
# 0  Kurtosis and Bitcoin: A Quantitative Analysis
# 0  Kurtosis and Bitcoin: A Quantitative Analysis
# 0  Kurtosis and Bitcoin: A Quantitative Analysis
# 0  Kurtosis and Bitcoin: A Quantitative Analysis
# 0  Kurtosis and Bitcoin: A Quantitative Analysis
#
#                                                 text            Tags
# 0  Financial markets are chaotic. So chaotic, eve...         Bitcoin
# 0  Financial markets are chaotic. So chaotic, eve...      Blockchain
# 0  Financial markets are chaotic. So chaotic, eve...         Finance
# 0  Financial markets are chaotic. So chaotic, eve...      Investment
# 0  Financial markets are chaotic. So chaotic, eve...  Cryptocurrency

# %%
new_articles.shape
# Out:
# (1593, 4)

# %% [markdown]
# Cargamos el nuevo dataset

# %%
new_articles.to_csv('text_classifier.csv')
