# %%
import re
import numpy as np
import pandas as pd
import spacy
import string
import matplotlib.pyplot as plt
import seaborn as sns
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
# %matplotlib inline

# %%
file = pd.read_csv('text_classifier.csv', usecols=['id', 'title', 'text', 'Tags'])

# %%
file.head()
# Out:
#                                                   id  \
# 0  https://hackernoon.com/whats-the-best-smartpho...
# 1  https://hackernoon.com/whats-the-best-smartpho...
# 2  https://hackernoon.com/whats-the-best-smartpho...
# 3  https://hackernoon.com/whats-the-best-smartpho...
# 4  https://hackernoon.com/blockchain-what-the-hel...
#
#                                                title  \
# 0  What the Best Smartphone for keeping your Conv...
# 1  What the Best Smartphone for keeping your Conv...
# 2  What the Best Smartphone for keeping your Conv...
# 3  What the Best Smartphone for keeping your Conv...
# 4        Blockchain: What the Hell is a Merkle Tree?
#
#                                                 text            Tags
# 0  In the world of today, personal data like our ...      Blockchain
# 1  In the world of today, personal data like our ...         Bitcoin
# 2  In the world of today, personal data like our ...  Cryptocurrency
# 3  In the world of today, personal data like our ...       Education
# 4  No you can find this kind of a tree in the for...      Blockchain

# %%
file.Tags.nunique()
# Out:
# 407

# %%
#create a dataframe copy to remove duplicated id's

file_unique_urls = file.copy()
file_unique_urls.drop_duplicates(subset='id', inplace=True)

# %%
file_unique_urls.text.dtype
# Out:
# dtype('O')

# %%
#display tags

with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    print(file['Tags'].value_counts())
# Out:
# Latest Tech Stories               67
# Cryptocurrency                    49
# Hackernoon Top Story              29
# Artificial Intelligence           24
# Crypto                            22
# Blockchain                        17
# Machine Learning                  16
# Coding                            15
# Startups                          15
# Ai                                14
# Programming                       13
# Data Science                       9
# Deep Learning                      9
# Software Development               9
# Bitcoin                            8
# Ethereum                           8
# Education                          7
# Libra                              6
# Javascript                         6
# Facebook Libra                     6
# Facebook                           6
# Startup                            6
# Latest Tech Story                  4
# Privacy                            3
# Calibra                            3
# Intotheblock                       3
# Crypto Trading                     3
# Productivity                       3
# Cryptocurrency Investment          3
# Futurism                           3
# Invector Labs                      3
# Venture Capital                    3
# Futurist                           3
# Blockchain Development             3
# Technology                         2
# Career                             2
# Security Tokens                    2
# Cofounder                          2
# Intelligence                       2
# Singapore                          2
# Integration                        2
# Product Management                 2
# Decentralization                   2
# Cryptocurrency Trading             2
# Crowdsourcing                      2
# Tara Ai                            2
# Ieo                                2
# Ai Trends                          2
# Data Privacy                       2
# David Smooke                       2
# Initial Exchange Offering          2
# Dapp                               2
# Ml                                 2
# Founders                           2
# Internship                         2
# Trading                            2
# Beginners                          2
# Dapps                              2
# Tech Debt                          2
# Finance                            2
# Technical Debt                     2
# Brand As Author                    2
# Entrepreneurship                   2
# Technical Debt Strategies          2
# Fintech                            2
# Machine Learning Interviews        2
# Automation                         2
# Api                                2
# Machine Learning Heroes            1
# Digitalization                     1
# Crypto Startups                    1
# Tech Career                        1
# Ads                                1
# Energy                             1
# Security Tokenomics                1
# Tech Transparency                  1
# Weak Ai                            1
# Bandwagon Effect                   1
# C                                  1
# Algo Based Contracts               1
# Data Collection                    1
# Communication                      1
# Hackernoon                         1
# Killing Globalisation              1
# Problems With Investing            1
# Noonies 2019                       1
# Cryptocurrencies                   1
# Killing Globalization              1
# Investors                          1
# Development                        1
# Developer                          1
# Market Making                      1
# Investing In Crypto                1
# Estimating                         1
# Last Week In Ai                    1
# Aws                                1
# Crypto Jobs                        1
# Cloud                              1
# Neural Networks                    1
# Loss Aversion                      1
# Build A Side Project               1
# Coding Tests                       1
# Team building                      1
# Another Tech Thought               1
# Copy Paste Exploits                1
# Merkle Tree                        1
# Security                           1
# What Is A Merkle Tree              1
# Junior Developer                   1
# Monorepo                           1
# Ai Globalization                   1
# Eos Account                        1
# Job Automation                     1
# Python                             1
# Biotech                            1
# Ml Frameworks                      1
# Eos Wallet                         1
# Business                           1
# Model Deployment                   1
# Gambling And Lotteries             1
# Crowdwork                          1
# Blockchain Jobs                    1
# 2fa Exploits                       1
# Blockchain Iot                     1
# Startup hiring                     1
# Crypto Winter                      1
# Bootstrapping                      1
# Stablecoin                         1
# Smart City                         1
# Trader Life                        1
# Aws Lambda                         1
# Exponential View                   1
# Name: Tags, dtype: int64

# %%
#start preprocessing
nlp = spacy.load('en_core_web_sm')
parser = English()

# %%
#create a words tokenizer

def words_tokenizer(text):
    tokens = parser(text)
    filtered_tokens = []
    for word in tokens:
        lemma = word.lemma_.lower().strip() 
        if lemma not in STOP_WORDS and re.search ('^[a-zA-Z]+$', lemma):
            if lemma.endswith('ly'):
                continue
            filtered_tokens.append(lemma)
    return list(set(filtered_tokens))

# %%
words_tokenizer(file_unique_urls.text.values[2])
# Out:
# ['list',
#  'outcome',
#  'time',
#  'lazy',
#  'political',
#  'come',
#  'run',
#  'custom',
#  'sell',
#  'introduce',
#  'bake',
#  'immature',
#  'semi',
#  'complement',
#  'asset',
#  'wave',
#  'point',
#  'steady',
#  'specific',
#  'data',
#  'like',
#  'recognize',
#  'pattern',
#  'relationship',
#  'surprise',
#  'role',
#  'prediction',
#  'sale',
#  'bitcoin',
#  'serve',
#  'bear',
#  'markets',
#  'significant',
#  'free',
#  'preposterous',
#  'tend',
#  'crowdsourced',
#  'extract',
#  'misinterpret',
#  'know',
#  'idea',
#  'storm',
#  'relatable',
#  'predictor',
#  'bombard',
#  'predict',
#  'strange',
#  'price',
#  'mean',
#  'score',
#  'zero',
#  'look',
#  'learn',
#  'public',
#  'tailor',
#  'material',
#  'science',
#  'result',
#  'subjective',
#  'channel',
#  'linear',
#  'experiment',
#  'element',
#  'crypto',
#  'behavior',
#  'try',
#  'shoot',
#  'recursive',
#  'construction',
#  'class',
#  'hard',
#  'market',
#  'doesn',
#  'fee',
#  'assistant',
#  'opinion',
#  'questionable',
#  'explanation',
#  'population',
#  'china',
#  'isolate',
#  'speculation',
#  'need',
#  'large',
#  'provider',
#  'statistic',
#  'numb',
#  'weight',
#  'bite',
#  'core',
#  'fantasy',
#  'mention',
#  'event',
#  'ask',
#  'increase',
#  'election',
#  'favorite',
#  'case',
#  'mathematical',
#  'use',
#  'tool',
#  'ownership',
#  'sort',
#  'strategy',
#  'proof',
#  'investor',
#  'complex',
#  'financial',
#  'social',
#  'silver',
#  'don',
#  'movements',
#  'flexible',
#  'float',
#  'metric',
#  'different',
#  'technique',
#  'prefer',
#  'news',
#  'unknown',
#  'read',
#  'tip',
#  'retail',
#  'flaw',
#  'claim',
#  'analyze',
#  'chartists',
#  'theory',
#  'formula',
#  'hear',
#  'current',
#  'growth',
#  'technical',
#  'reason',
#  'half',
#  'answer',
#  'area',
#  'remain',
#  'help',
#  'simple',
#  'offer',
#  'dynamic',
#  'discussion',
#  'propense',
#  'work',
#  'space',
#  'twitter',
#  'cite',
#  'today',
#  'coinbase',
#  'model',
#  'rigor',
#  'demographic',
#  'ridiculous',
#  'analytics',
#  'determine',
#  'non',
#  'door',
#  'fact',
#  'diva',
#  'complicated',
#  'dig',
#  'mainstream',
#  'period',
#  'robust',
#  'extracting',
#  'build',
#  'new',
#  'static',
#  'equivalent',
#  'nascent',
#  'realize',
#  'analytic',
#  'irrational',
#  'require',
#  'base',
#  'machine',
#  'watson',
#  'basic',
#  'enigma',
#  'recipe',
#  'characteristic',
#  'factor',
#  'dissect',
#  'adapt',
#  'money',
#  'evaluate',
#  'escape',
#  'popularity',
#  'experimentation',
#  'way',
#  'sec',
#  'sentiment',
#  'signal',
#  'feed',
#  'apis',
#  'grade',
#  'easy',
#  'invest',
#  'product',
#  'society',
#  'perfect',
#  'disaster',
#  'regardless',
#  'lack',
#  'people',
#  'play',
#  'noise',
#  'validation',
#  'understand',
#  'available',
#  'mimic',
#  'mislead',
#  'analyzing',
#  'important',
#  'methodology',
#  'research',
#  'effective',
#  'exception',
#  'golden',
#  'token',
#  'illogical',
#  'bullet',
#  'level',
#  'real',
#  'mature',
#  'single',
#  'age',
#  'trend',
#  'variable',
#  'normal',
#  'deep',
#  'telegram',
#  'wisdom',
#  'condition',
#  'cornerstone',
#  'measure',
#  'vendor',
#  'regular',
#  'relevant',
#  'impact',
#  'crowd',
#  'common',
#  'fundamental',
#  'find',
#  'human',
#  'trader',
#  'datum',
#  'analysis',
#  'reveal',
#  'history',
#  'formulate',
#  'complementary',
#  'meaningful',
#  'intelligence',
#  'generation',
#  'outrageous',
#  'performance',
#  'example',
#  'involve',
#  'thousand',
#  'difference',
#  'sophisticate',
#  'describe',
#  'information',
#  'add',
#  'change',
#  'network',
#  'combine',
#  'native',
#  'correlation',
#  'produce']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#vectorization of token words and document-term matrix creation.

tfidf_vectorizer = TfidfVectorizer(min_df=0.15, max_df= 0.9, tokenizer=words_tokenizer)
terms_matrix = tfidf_vectorizer.fit_transform(file_unique_urls.text)
print("shape of the matrix:", terms_matrix.shape)
# Out:
# shape of the matrix: (101, 458)

# %%
#Feature words in docs

terms = tfidf_vectorizer.get_feature_names()
print("The number of feature words in all the texts is", len(terms))
# Out:
# The number of feature words in all the texts is 458

# %%
#Density matrix

doc_term_matrix = terms_matrix.todense()

# %%
#create dataframe

df_words = pd.DataFrame(doc_term_matrix, columns=terms, index=file_unique_urls.title)
df_words.head()
# Out:
#                                                     ability      able  \
# title
# What the Best Smartphone for keeping your Conve...      0.0  0.061334
# Blockchain: What the Hell is a Merkle Tree?             0.0  0.092491
# Data Signals vs. Noise: Misleading Metrics and ...      0.0  0.000000
# A crypto-trader diary  week 1                           0.0  0.000000
# Understanding Cryptocurrency Development                0.0  0.000000
#
#                                                       access    accord  \
# title
# What the Best Smartphone for keeping your Conve...  0.072445  0.000000
# Blockchain: What the Hell is a Merkle Tree?         0.000000  0.000000
# Data Signals vs. Noise: Misleading Metrics and ...  0.000000  0.000000
# A crypto-trader diary  week 1                       0.000000  0.072502
# Understanding Cryptocurrency Development            0.000000  0.081641
#
#                                                      account  achieve  act  \
# title
# What the Best Smartphone for keeping your Conve...  0.000000  0.08131  0.0
# Blockchain: What the Hell is a Merkle Tree?         0.000000  0.00000  0.0
# Data Signals vs. Noise: Misleading Metrics and ...  0.000000  0.00000  0.0
# A crypto-trader diary  week 1                       0.073534  0.00000  0.0
# Understanding Cryptocurrency Development            0.082802  0.00000  0.0
#
#                                                       action  activity  \
# title
# What the Best Smartphone for keeping your Conve...  0.084368       0.0
# Blockchain: What the Hell is a Merkle Tree?         0.000000       0.0
# Data Signals vs. Noise: Misleading Metrics and ...  0.000000       0.0
# A crypto-trader diary  week 1                       0.000000       0.0
# Understanding Cryptocurrency Development            0.000000       0.0
#
#                                                          add  ...  win  \
# title                                                         ...
# What the Best Smartphone for keeping your Conve...  0.000000  ...  0.0
# Blockchain: What the Hell is a Merkle Tree?         0.000000  ...  0.0
# Data Signals vs. Noise: Misleading Metrics and ...  0.089989  ...  0.0
# A crypto-trader diary  week 1                       0.000000  ...  0.0
# Understanding Cryptocurrency Development            0.080513  ...  0.0
#
#                                                         word      work  \
# title
# What the Best Smartphone for keeping your Conve...  0.071357  0.043265
# Blockchain: What the Hell is a Merkle Tree?         0.000000  0.065244
# Data Signals vs. Noise: Misleading Metrics and ...  0.000000  0.058625
# A crypto-trader diary  week 1                       0.000000  0.046581
# Understanding Cryptocurrency Development            0.086510  0.000000
#
#                                                        world     worry  \
# title
# What the Best Smartphone for keeping your Conve...  0.050761  0.000000
# Blockchain: What the Hell is a Merkle Tree?         0.000000  0.000000
# Data Signals vs. Noise: Misleading Metrics and ...  0.000000  0.000000
# A crypto-trader diary  week 1                       0.000000  0.000000
# Understanding Cryptocurrency Development            0.000000  0.106382
#
#                                                        worth  wouldn  \
# title
# What the Best Smartphone for keeping your Conve...  0.000000     0.0
# Blockchain: What the Hell is a Merkle Tree?         0.000000     0.0
# Data Signals vs. Noise: Misleading Metrics and ...  0.000000     0.0
# A crypto-trader diary  week 1                       0.090834     0.0
# Understanding Cryptocurrency Development            0.000000     0.0
#
#                                                        write     wrong  \
# title
# What the Best Smartphone for keeping your Conve...  0.000000  0.072445
# Blockchain: What the Hell is a Merkle Tree?         0.000000  0.000000
# Data Signals vs. Noise: Misleading Metrics and ...  0.000000  0.000000
# A crypto-trader diary  week 1                       0.072502  0.077998
# Understanding Cryptocurrency Development            0.000000  0.000000
#
#                                                         year
# title
# What the Best Smartphone for keeping your Conve...  0.050761
# Blockchain: What the Hell is a Merkle Tree?         0.000000
# Data Signals vs. Noise: Misleading Metrics and ...  0.000000
# A crypto-trader diary  week 1                       0.000000
# Understanding Cryptocurrency Development            0.000000
#
# [5 rows x 458 columns]

# %%
#Cosine similarity

from sklearn.metrics.pairwise import cosine_similarity

# %%
dist = 1-cosine_similarity(doc_term_matrix)

# %%
dist.shape, dist.dtype
# Out:
# ((101, 101), dtype('float64'))

# %%
import warnings
from umap import UMAP

# %%
def getUmap(dataset, n_components):
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        umap = UMAP(n_components=n_components, n_epochs=15 , random_state=42).fit_transform(dataset)
        return pd.DataFrame(umap, columns=[f'emb_{i+1}' for i in range(n_components)])

# %%
#draw plot for umap

umap_df = get_umap(df_words, 3)
umap_df.head()
# Out:
#       emb_1     emb_2     emb_3
# 0  1.737671 -0.879085 -0.638790
# 1 -0.729744  1.262631 -0.678082
# 2  1.292054 -0.611840  1.752772
# 3  0.557604  1.654625  0.262814
# 4  0.532842  0.340832 -1.261642

# %%
from hdbscan import HDBSCAN

# %%
def getClusters(umap):
    hdbscan = HDBSCAN(min_cluster_size=5)
    clusters = hdbscan.fit_predict(umap_df)
    return clusters

plt.scatter(umap_df.emb_1, umap_df.emb_2, c=get_clusters(umap_df))

# %%
def articlesinClusters(clusters):
    return text_unique_urls
# Out:
# [-1  0  1]
#    0
# 0 -1
# 1 -1
# 2 -1
# 3 -1
# 4 -1

# %%
hdbscan = HDBSCAN(min_cluster_size=5)

clusters = hdbscan.fit(umap_df)
clusters.outlier_scores_
# Out:
# array([0.4253456 , 0.35532371, 0.04647314, 0.29386543, 0.36706536,
#        0.15210612, 0.37472886, 0.20601671, 0.37215532, 0.39799675,
#        0.5011646 , 0.22291907, 0.32157521, 0.55493545, 0.34286837,
#        0.11109901, 0.19198117, 0.        , 0.291091  , 0.24193491,
#        0.        , 0.31336062, 0.09045879, 0.34140609, 0.13746242,
#        0.03204937, 0.        , 0.13746242, 0.2136784 , 0.06111122,
#        0.14842616, 0.10651304, 0.09848337, 0.22291907, 0.        ,
#        0.07616841, 0.        , 0.04901706, 0.10620711, 0.2097445 ,
#        0.        , 0.14957594, 0.08877376, 0.        , 0.20506682,
#        0.        , 0.03204937, 0.        , 0.11869007, 0.51232067,
#        0.37290551, 0.25989151, 0.21417596, 0.20063013, 0.25497454,
#        0.25702026, 0.10975763, 0.18756791, 0.22058194, 0.284066  ,
#        0.07568533, 0.09848337, 0.26480996, 0.13444096, 0.24244119,
#        0.03180324, 0.24826583, 0.20547392, 0.11444227, 0.07317399,
#        0.3515925 , 0.07345366, 0.10222407, 0.        , 0.3890611 ,
#        0.08635848, 0.04901706, 0.        , 0.05461752, 0.12556785,
#        0.05000589, 0.06653997, 0.05707632, 0.05537479, 0.04901706,
#        0.        , 0.05000589, 0.06112237, 0.073618  , 0.02282773,
#        0.05000589, 0.00317929, 0.14460351, 0.        , 0.        ,
#        0.11741362, 0.17531874, 0.07512459, 0.05000589, 0.17531874,
#        0.03904789])

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig= plt.figure(figsize=(10,8))
ax= fig.add_subplot(111, projection='3d')
ax.scatter(umap_df.emb_1, umap_df.emb_2, umap_df.emb_3, marker='*' ,c=get_clusters(umap_df), s=20)
plt.show()
